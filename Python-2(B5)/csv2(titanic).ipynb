# %%
import pandas as pd
import numpy as np

df=pd.read_csv("titanic.csv")
print(df)
print()
df.head()
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df.describe()
# Out:
#             pclass          age        sibsp        parch         fare  \
# count  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000
# mean      2.294882    29.881135     0.498854     0.385027    33.295479
# std       0.837836    14.413500     1.041658     0.865560    51.758668
# min       1.000000     0.166700     0.000000     0.000000     0.000000
# 25%       2.000000    21.000000     0.000000     0.000000     7.895800
# 50%       3.000000    28.000000     0.000000     0.000000    14.454200
# 75%       3.000000    39.000000     1.000000     0.000000    31.275000
# max       3.000000    80.000000     8.000000     9.000000   512.329200
#
#           survived
# count  1309.000000
# mean      0.381971
# std       0.486055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.nunique()
# Out:
# pclass         3
# name        1307
# sex            2
# age           98
# sibsp          7
# parch          8
# ticket       929
# fare         281
# cabin        186
# embarked       3
# survived       2
# dtype: int64

# %%
df.shape
# Out:
# (1309, 11)

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
(df['sex']=='male').value_counts()
# Out:
# sex
# True     843
# False    466
# Name: count, dtype: int64

# %%
df['sex'].value_counts('male')*100
# Out:
# sex
# male      64.400306
# female    35.599694
# Name: proportion, dtype: float64

# %%
(df['sex']=='male').value_counts()

# %%
df.isnull().sum()
# Out:
# pclass         0
# name           0
# sex            0
# age          263
# sibsp          0
# parch          0
# ticket         0
# fare           1
# cabin       1014
# embarked       2
# survived       0
# dtype: int64

# %%
df['age']=df['age'].fillna(df['age'].mean())
df.isnull().sum()
# Out:
# pclass         0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin       1014
# embarked       2
# survived       0
# dtype: int64

# %%
df['fare']=df['fare'].fillna(df['fare'].median())
df.isnull().sum()
# Out:
# pclass         0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin       1014
# embarked       2
# survived       0
# dtype: int64

# %% [markdown]
# #### object:Mode     and    int,float : Mean,Median

# %%
df['embarked']=df['embarked'].fillna(df['embarked'].mode()[0])
df.isnull().sum()
# Out:
# pclass         0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin       1014
# embarked       0
# survived       0
# dtype: int64

# %%
df['cabin']=df['cabin'].fillna(method="bfill")
df.isnull().sum()
# Out:
# pclass       0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin       59
# embarked     0
# survived     0
# dtype: int64

# %%
df['cabin']=df['cabin'].fillna(method="ffill")
df.isnull().sum()
# Out:
# pclass      0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# cabin       0
# embarked    0
# survived    0
# dtype: int64

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("titanic.csv")
#print(df)
df.head(10)
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 5       1                              Anderson, Mr. Harry    male  48.0000
# 6       1                Andrews, Miss. Kornelia Theodosia  female  63.0000
# 7       1                           Andrews, Mr. Thomas Jr    male  39.0000
# 8       1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0000
# 9       1                          Artagaveytia, Mr. Ramon    male  71.0000
#
#    sibsp  parch    ticket      fare    cabin embarked  survived
# 0      0      0     24160  211.3375       B5        S         1
# ...

# %%
df.dtypes
# Out:
# pclass        int64
# name         object
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# ticket       object
# fare        float64
# cabin        object
# embarked     object
# survived      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# pclass         0
# name           0
# sex            0
# age          263
# sibsp          0
# parch          0
# ticket         0
# fare           1
# cabin       1014
# embarked       2
# survived       0
# dtype: int64

# %%
df.shape
# Out:
# (1309, 11)

# %%
df=df.dropna(how='all')

# %%
df.shape
# Out:
# (1309, 11)

# %%
df.drop(columns='age')
# Out:
#       pclass                                             name     sex  sibsp  \
# 0          1                    Allen, Miss. Elisabeth Walton  female      0
# 1          1                   Allison, Master. Hudson Trevor    male      1
# 2          1                     Allison, Miss. Helen Loraine  female      1
# 3          1             Allison, Mr. Hudson Joshua Creighton    male      1
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      1
# ...      ...                                              ...     ...    ...
# 1304       3                             Zabour, Miss. Hileni  female      1
# 1305       3                            Zabour, Miss. Thamine  female      1
# 1306       3                        Zakarian, Mr. Mapriededer    male      0
# 1307       3                              Zakarian, Mr. Ortin    male      0
# 1308       3                               Zimmerman, Mr. Leo    male      0
#
# ...

# %%
df.drop(index=[0,2])
# Out:
#       pclass                                             name     sex  \
# 1          1                   Allison, Master. Hudson Trevor    male
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5          1                              Anderson, Mr. Harry    male
# 6          1                Andrews, Miss. Kornelia Theodosia  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df=df.drop("Gender",axis=1,errors="ignore")
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset="age",keep="first")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# Length: 1309, dtype: bool

# %%
df.duplicated(subset="age",keep="last")
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Length: 1309, dtype: bool

# %%
import pandas as pd
import numpy as np

data={"id":[1,2,2,3,4],"Name":["Amit","Priya","Raj","Rahul","Priya"],"Marks":[80,35,75,85,65],"City":["Ahmedabad","Rajkot","Rajkot","Surat","Ahmedabad"]}
df=pd.DataFrame(data)
print(df)
# Out:
#    id   Name  Marks       City
# 0   1   Amit     80  Ahmedabad
# 1   2  Priya     35     Rajkot
# 2   2    Raj     75     Rajkot
# 3   3  Rahul     85      Surat
# 4   4  Priya     65  Ahmedabad

# %%
df.duplicated(subset="City")
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df.duplicated(subset="City",keep="first")
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df.duplicated(subset="City",keep="last")
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool
